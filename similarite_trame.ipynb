# %% [markdown]
# CHARGER ES DONNEES

# %%
import pandas as pd
films = pd.read_csv('./donnees/export_films.csv', sep='\t', low_memory=False)
films_personnes = pd.read_csv('./donnees/export_films_personnes.csv',sep='\t', low_memory=False)

# %% [markdown]
# on explode les colonnes en utilisant la fonction eval

# %%
films = films[(films['genres_x'].str.contains('Movie')==False)]
films
# Out:
#        Unnamed: 0.1  Unnamed: 0  adult     budget  \
# 0                 0          70  False   12800000
# 1                 1         109  False  140000000
# 2                 2         133  False   30000000
# 3                 3         154  False  200000000
# 4                 4         196  False    2000000
# ...             ...         ...    ...        ...
# 11011         12765      767462  False          0
# 11012         12767      768121  False          0
# 11013         12768      768702  False          0
# 11014         12769      769648  False          0
# 11015         12770      769907  False          0
#
#                                                 genres_x  id_tmdb    imdb_id  \
# 0                                     ['Drama', 'Crime']       16  tt0168629
# 1                     ['Adventure', 'Fantasy', 'Action']       22  tt0325980
# 2                                    ['Action', 'Crime']       24  tt0266697
# 3                     ['Adventure', 'Fantasy', 'Action']       58  tt0383574
# 4                         ['Thriller', 'Crime', 'Drama']       67  tt0445620
# ...                                                  ...      ...        ...
# 11011                                          ['Drama']   215034  tt3118628
# 11012                                          ['Drama']   219173  tt1576452
# 11013                                         ['Action']   222409  tt1512732
# 11014                                    ['Documentary']   228655  tt2007418
# 11015  ['Thriller', 'Horror', 'Action', 'Adventure', ...   231003  tt2011045
#
#       original_language                                     original_title  \
# 0                    en                                 Dancer in the Dark
# 1                    en  Pirates of the Caribbean: The Curse of the Bla...
# 2                    en                                  Kill Bill: Vol. 1
# 3                    en         Pirates of the Caribbean: Dead Man's Chest
# 4                    en                                       Paradise Now
# ...                 ...                                                ...
# 11011                en                                           Bastardo
# 11012                es                                       Por tu culpa
# 11013                en                                            Braille
# 11014                fr               Les trois disparitions de Soad Hosni
# 11015                en                                    Hombre Y Tierra
#
#                                                 overview  ...     revenue  \
# 0      Selma, a Czech immigrant on the verge of blind...  ...    40031879
# 1      Jack Sparrow, a freewheeling 18th-century pira...  ...   655011224
# 2      An assassin is shot by her ruthless employer, ...  ...   180906076
# 3      Captain Jack Sparrow works his way out of a bl...  ...  1065659812
# 4      Two childhood friends are recruited for a suic...  ...     3395627
# ...                                                  ...  ...         ...
# 11011  Larger-than-life characters populate director ...  ...           0
# 11012  Are we what others see, or are we what we allo...  ...           0
# 11013  Nick's blindness is symbolic to his regret for...  ...           0
# 11014  This haunting and beautifully formed documenta...  ...           0
# 11015  Mauro Bosque was an adventurer, a survivalist,...  ...           0
#
#       runtime          spoken_languages    status  \
# 0         141                    ['en']  Released
# 1         143                    ['en']  Released
# 2         111        ['en', 'ja', 'fr']  Released
# 3         151  ['en', 'tr', 'el', 'zh']  Released
# 4          90              ['ar', 'en']  Released
# ...       ...                       ...       ...
# 11011     106                    ['ar']  Released
# 11012      87                    ['es']  Released
# 11013      90                        []  Released
# 11014      70        ['ar', 'en', 'fr']  Released
# 11015      82                    ['es']  Released
#
#                                                    title  vote_average  \
# 0                                     Dancer in the Dark         7.881
# 1      Pirates of the Caribbean: The Curse of the Bla...         7.800
# 2                                      Kill Bill: Vol. 1         7.970
# 3             Pirates of the Caribbean: Dead Man's Chest         7.340
# 4                                           Paradise Now         6.941
# ...                                                  ...           ...
# 11011                                            Bastard         7.000
# 11012                                    It's Your Fault         6.000
# 11013                                            Braille         6.000
# 11014             The Three Disappearances of Soad Hosni         6.000
# 11015                                    Hombre Y Tierra         5.200
#
#       vote_count  directors                                  writers  year
# 0           1555  nm0001885                      nm0001885,nm0797604  2000
# 1          18710  nm0893659  nm0254645,nm0744429,nm0064181,nm0938684  2003
# 2          15748  nm0000233                      nm0000233,nm0000235  2003
# 3          14465  nm0893659  nm0254645,nm0744429,nm0064181,nm0938684  2006
# 4            219  nm0009463            nm0009463,nm1178208,nm0388293  2005
# ...          ...        ...                                      ...   ...
# 11011          1  nm0067946                      nm0067946,nm2144991  2013
# 11012          5  nm1318393                      nm1318393,nm1196938  2010
# 11013          1  nm2065393                      nm2065393,nm1863128  2011
# 11014          1  nm1645751                                nm1645751  2011
# 11015          3  nm1870338                      nm1870338,nm2566773  2011
#
# [10994 rows x 24 columns]

# %%
films['genre'] = films['genres_x'].apply(eval)

# %%
films_prepa = films.explode('genre')

# %%
films_prepa_cat = films_prepa[['genre']]
films_cat_dummies = pd.get_dummies(films_prepa_cat)

# %%
films_cat_dummies
# Out:
#        genre_Action  genre_Adventure  genre_Animation  genre_Comedy  \
# 0             False            False            False         False
# 0             False            False            False         False
# 1             False             True            False         False
# 1             False            False            False         False
# 1              True            False            False         False
# ...             ...              ...              ...           ...
# 11015         False            False            False         False
# 11015         False            False            False         False
# 11015          True            False            False         False
# 11015         False             True            False         False
# 11015         False            False            False         False
#
#        genre_Crime  genre_Documentary  genre_Drama  genre_Family  \
# 0            False              False         True         False
# 0             True              False        False         False
# 1            False              False        False         False
# 1            False              False        False         False
# 1            False              False        False         False
# ...            ...                ...          ...           ...
# 11015        False              False        False         False
# 11015        False              False        False         False
# 11015        False              False        False         False
# 11015        False              False        False         False
# 11015        False              False         True         False
#
#        genre_Fantasy  genre_History  genre_Horror  genre_Music  genre_Mystery  \
# 0              False          False         False        False          False
# 0              False          False         False        False          False
# 1              False          False         False        False          False
# 1               True          False         False        False          False
# 1              False          False         False        False          False
# ...              ...            ...           ...          ...            ...
# 11015          False          False         False        False          False
# 11015          False          False          True        False          False
# 11015          False          False         False        False          False
# 11015          False          False         False        False          False
# 11015          False          False         False        False          False
#
#        genre_Romance  genre_Science Fiction  genre_Thriller  genre_War  \
# 0              False                  False           False      False
# 0              False                  False           False      False
# 1              False                  False           False      False
# 1              False                  False           False      False
# 1              False                  False           False      False
# ...              ...                    ...             ...        ...
# 11015          False                  False            True      False
# 11015          False                  False           False      False
# 11015          False                  False           False      False
# 11015          False                  False           False      False
# 11015          False                  False           False      False
#
#        genre_Western
# 0              False
# 0              False
# 1              False
# 1              False
# 1              False
# ...              ...
# 11015          False
# 11015          False
# 11015          False
# 11015          False
# 11015          False
#
# [26344 rows x 18 columns]

# %%
films_prepa['original_language'].value_counts()
# Out:
# original_language
# en    9385
# fr    4994
# ja    2305
# hi     972
# ko     971
#       ...
# gu       1
# xh       1
# mg       1
# kl       1
# sw       1
# Name: count, Length: 90, dtype: int64

# %%
films_prepa.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'adult', 'budget', 'genres_x', 'id_tmdb',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'title',
#        'vote_average', 'vote_count', 'directors', 'writers', 'year', 'genre',
#        'pays', 'langue_parlee'],
#       dtype='object')

# %% [markdown]
# 2. SAVOIR CE QU ON VEUT PREDIRE

# %%
#colonnes à sup: adults, budget id_tmdb, imbd, original title, overview,poster_path,, 'release_date',
#'revenue', 'vote_count''directors', 'writers','spoken_languages',,production_countries

# %%
#colonne à garder : genre',original_language','popularity','runtime', ,'vote_average', 'year'

# %% [markdown]
# 3. DECLARATION

# %%
X = films[['genres_x','original_language','popularity','production_countries','runtime', 'spoken_languages','title','vote_average', 'year',]]

# %%
# import des tables avec la librairie pandas
import pandas as pd

df_name = pd.read_csv("./Data/IMDb/name.basics.tsv", sep='\t',nrows=10000)

# %%
df_akas = pd.read_csv("./Data/IMDb/title.akas.tsv", sep='\t',nrows=10000)

# %%
df_basics = pd.read_csv("./Data/IMDb/title.basics.tsv", sep='\t',nrows=10000)

# %%
df_crew = pd.read_csv("./Data/IMDb/title.crew.tsv", sep='\t',nrows=10000)

# %%
df_episode = pd.read_csv("./Data/IMDb/title.episode.tsv", sep='\t',nrows=10000)

# %%
df_principals = pd.read_csv("./Data/IMDb/title.principals.tsv", sep='\t',nrows=10000)

# %%
df_ratings = pd.read_csv("./Data/IMDb/title.ratings.tsv", sep='\t',nrows=10000)

# %%
df_tmbd = pd.read_csv("./Data/IMDb/tmdb_full.csv", sep=',',nrows=10000)

# %%
df_tmbd.head(2)
# Out:
#    adult                     backdrop_path  budget         genres homepage  \
# 0  False  /dvQj1GBZAZirz1skEEZyWH2ZqQP.jpg       0     ['Comedy']      NaN
# 1  False                               NaN       0  ['Adventure']      NaN
#
#      id    imdb_id original_language       original_title  \
# 0  3924  tt0029927                en              Blondie
# 1  6124  tt0011436                de  Der Mann ohne Namen
#
#                                             overview  ...  runtime  \
# 0  Blondie and Dagwood are about to celebrate the...  ...       70
# 1                                                NaN  ...      420
#
#   spoken_languages    status  \
# 0           ['en']  Released
# 1               []  Released
#
#                                              tagline  \
# 0  The favorite comic strip of millions at last o...
# 1                                                NaN
#
#                            title  video vote_average vote_count  \
# ...

# %%
df_name.head(5)
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                     primaryProfession                           knownForTitles
# 0        actor,miscellaneous,producer  tt0050419,tt0072308,tt0053137,tt0027125
# 1  actress,soundtrack,archive_footage  tt0037382,tt0075213,tt0117057,tt0038355
# 2   actress,music_department,producer  tt0057345,tt0049189,tt0056404,tt0054452
# 3       actor,writer,music_department  tt0072562,tt0077975,tt0080455,tt0078723
# 4               writer,director,actor  tt0050986,tt0069467,tt0050976,tt0083922

# %%
df_akas.head(5)
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Carmencita     \N       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3                 Carmencita     US       \N
# 3  tt0000001         4  Carmencita - spanyol tánc     HU       \N
# 4  tt0000001         5                 Καρμενσίτα     GR       \N
#
#          types     attributes  isOriginalTitle
# 0     original             \N                1
# 1           \N  literal title                0
# 2  imdbDisplay             \N                0
# 3  imdbDisplay             \N                0
# 4  imdbDisplay             \N                0

# %%
df_basics.head(10)
# Out:
#       tconst titleType                                 primaryTitle  \
# 0  tt0000001     short                                   Carmencita
# 1  tt0000002     short                       Le clown et ses chiens
# 2  tt0000003     short                                 Poor Pierrot
# 3  tt0000004     short                                  Un bon bock
# 4  tt0000005     short                             Blacksmith Scene
# 5  tt0000006     short                            Chinese Opium Den
# 6  tt0000007     short  Corbett and Courtney Before the Kinetograph
# 7  tt0000008     short       Edison Kinetoscopic Record of a Sneeze
# 8  tt0000009     movie                                   Miss Jerry
# 9  tt0000010     short                          Leaving the Factory
#
#                                  originalTitle  isAdult startYear endYear  \
# 0                                   Carmencita        0      1894      \N
# ...

# %%
df_crew.head(5)
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690      \N
# 1  tt0000002  nm0721526      \N
# 2  tt0000003  nm0721526      \N
# 3  tt0000004  nm0721526      \N
# 4  tt0000005  nm0005690      \N

# %%
df_episode.head(5)
# Out:
#       tconst parentTconst seasonNumber episodeNumber
# 0  tt0031458   tt32857063           \N            \N
# 1  tt0041951    tt0041038            1             9
# 2  tt0042816    tt0989125            1            17
# 3  tt0042889    tt0989125           \N            \N
# 4  tt0043426    tt0040051            3            42

# %%
df_principals.head(5)
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0005690         producer                 producer
# 3  tt0000001         4  nm0374658  cinematographer  director of photography
# 4  tt0000002         1  nm0721526         director                       \N
#
#   characters
# 0   ["Self"]
# 1         \N
# 2         \N
# 3         \N
# 4         \N

# %%
df_ratings.head(5)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2102
# 1  tt0000002            5.6       282
# 2  tt0000003            6.5      2121
# 3  tt0000004            5.4       182
# 4  tt0000005            6.2      2852

# %%
# import des tables avec la librairie pandas
import pandas as pd

df_name = pd.read_csv("./Data/IMDb/name.basics.tsv", sep='\t', nrows=1000)
df_akas = pd.read_csv("./Data/IMDb/title.akas.tsv", sep='\t', nrows=1000)
df_basics = pd.read_csv("./Data/IMDb/title.basics.tsv", sep='\t', nrows=1000)
df_crew = pd.read_csv("./Data/IMDb/title.crew.tsv", sep='\t', nrows=1000)
df_episode = pd.read_csv("./Data/IMDb/title.episode.tsv", sep='\t', nrows=1000)
df_principals = pd.read_csv("./Data/IMDb/title.principals.tsv", sep='\t', nrows=1000)
df_ratings = pd.read_csv("./Data/IMDb/title.ratings.tsv", sep='\t', nrows=1000)
df_tmbd = pd.read_csv("./Data/IMDb/tmdb_full.csv", sep=',', nrows=1000)

# %%
df_tmbd.head(2)
# Out:
#    adult                     backdrop_path  budget         genres homepage  \
# 0  False  /dvQj1GBZAZirz1skEEZyWH2ZqQP.jpg       0     ['Comedy']      NaN
# 1  False                               NaN       0  ['Adventure']      NaN
#
#      id    imdb_id original_language       original_title  \
# 0  3924  tt0029927                en              Blondie
# 1  6124  tt0011436                de  Der Mann ohne Namen
#
#                                             overview  ...  runtime  \
# 0  Blondie and Dagwood are about to celebrate the...  ...       70
# 1                                                NaN  ...      420
#
#   spoken_languages    status  \
# 0           ['en']  Released
# 1               []  Released
#
#                                              tagline  \
# 0  The favorite comic strip of millions at last o...
# 1                                                NaN
#
#                            title  video vote_average vote_count  \
# ...

# %%
df_name.value_counts()
# Out:
# nconst     primaryName        birthYear  deathYear  primaryProfession                 knownForTitles
# nm0000001  Fred Astaire       1899       1987       actor,miscellaneous,producer      tt0050419,tt0072308,tt0053137,tt0027125     1
# nm0000672  Meg Tilly          1960       \N         actress,writer,archive_footage    tt0085244,tt0088683,tt0086154,tt0106452     1
# nm0000659  Barbra Streisand   1942       \N         music_artist,actress,producer     tt0086619,tt0062994,tt0117057,tt0070903     1
# nm0000660  Tami Stronach      1972       \N         actress,producer,archive_footage  tt0088323,tt12623434,tt3222644,tt6557704    1
# nm0000661  Donald Sutherland  1935       2024       actor,producer,writer             tt1951264,tt0414387,tt0067309,tt1951265     1
#                                                                                                                                  ..
# ...
